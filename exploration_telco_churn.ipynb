# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

import jb_helper_functions_prep
from jb_helper_functions_prep import create_enc

import prep_telco
from prep_telco import prep_telco_df

from sklearn.model_selection import train_test_split

# %%
df = prep_telco_df()
df.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity    ...      \
# 0  No phone service             DSL             No    ...
# 1                No             DSL            Yes    ...
# 2                No             DSL            Yes    ...
# 3  No phone service             DSL            Yes    ...
# 4                No     Fiber optic             No    ...
#
#   onlinesecurity_enc onlinebackup_enc deviceprotection_enc techsupport_enc  \
# 0                  0                2                    0               0
# 1                  2                0                    2               0
# 2                  2                2                    0               0
# 3                  2                0                    2               2
# 4                  0                0                    0               0
#
#   streamingtv_enc streamingmovies_enc contract_enc paperlessbilling_enc  \
# 0               0                   0            0                    1
# 1               0                   0            1                    0
# 2               0                   0            0                    1
# 3               0                   0            1                    0
# 4               0                   0            0                    1
#
#    paymentmethod_enc  churn_enc
# 0                  2          0
# 1                  3          0
# 2                  3          1
# 3                  0          0
# 4                  2          1
#
# [5 rows x 38 columns]

# %%
train, test = train_test_split(df, test_size=.3, random_state=123, stratify=df[['churn_enc']])

# %% [markdown]
# ### A few first thoughts:
#
# ### Customers with higher monthly costs will churn more.
#
# ### Customers with a longer tenure will churn more and pay more per month.
#
# ### Customer with month-to-month contracts will churn more frequently.  They will also pay more per month as we would expect a company to have lower rates for a customer willing to sign a year or two contract.

# %%
train.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn', 'fullyear',
#        'gender_enc', 'partner_enc', 'dependents_enc', 'phoneservice_enc',
#        'multiplelines_enc', 'internetservice_enc', 'onlinesecurity_enc',
#        'onlinebackup_enc', 'deviceprotection_enc', 'techsupport_enc',
#        'streamingtv_enc', 'streamingmovies_enc', 'contract_enc',
#        'paperlessbilling_enc', 'paymentmethod_enc', 'churn_enc'],
#       dtype='object')

# %%
pd.DataFrame((train.groupby(['contract', 'churn'])['monthlycharges'].count())/(train.groupby('contract')['monthlycharges'].count()))
# Out:
#                       monthlycharges
# contract       churn
# Month-to-month No           0.573054
#                Yes          0.426946
# One year       No           0.888454
#                Yes          0.111546
# Two year       No           0.973639
#                Yes          0.026361

# %% [markdown]
# ### Looking above, we see that 42.7% of month-to-month customers did churn vs. 11.1% of one-year and 2.6% of two-year contract customers.

# %%
pd.DataFrame(train.groupby(['internetservice', 'contract'])['monthlycharges'].quantile(.25))
# Out:
#                                 monthlycharges
# internetservice contract
# DSL             Month-to-month         44.4500
#                 One year               53.7500
#                 Two year               59.9625
# Fiber optic     Month-to-month         76.5500
#                 One year               92.3000
#                 Two year               98.9500
# No              Month-to-month         19.6000
#                 One year               19.7000
#                 Two year               19.7500

# %%
pd.DataFrame(train.groupby(['internetservice', 'contract'])['monthlycharges'].quantile(.5))
# Out:
#                                 monthlycharges
# internetservice contract
# DSL             Month-to-month          50.250
#                 One year                60.950
#                 Two year                73.100
# Fiber optic     Month-to-month          85.700
#                 One year                99.900
#                 Two year               105.625
# No              Month-to-month          20.050
#                 One year                20.100
#                 Two year                20.350

# %%
pd.DataFrame(train.groupby(['internetservice', 'contract'])['monthlycharges'].mean())
# Out:
#                                 monthlycharges
# internetservice contract
# DSL             Month-to-month       50.362718
#                 One year             61.603050
#                 Two year             70.098190
# Fiber optic     Month-to-month       86.804274
#                 One year             98.655913
#                 Two year            104.118412
# No              Month-to-month       20.307345
#                 One year             20.883594
#                 Two year             21.717123

# %%
pd.DataFrame(train.groupby(['internetservice', 'contract'])['monthlycharges'].quantile(.75))
# Out:
#                                 monthlycharges
# internetservice contract
# DSL             Month-to-month         57.9500
#                 One year               71.5000
#                 Two year               82.4125
# Fiber optic     Month-to-month         95.3000
#                 One year              105.2500
#                 Two year              111.1125
# No              Month-to-month         20.4000
#                 One year               20.6500
#                 Two year               24.5875

# %% [markdown]
# ### In the four tables above, we see that for DSL and Fiber optic, that m-t-m customers are paying less than one and two year contract customers.  This is different than the original thought.  To try and answer this, is it because customers in the m-t-m contracts have a significantly lower tenure so their rates haven't increased yet?  (Think about what happens each year as you're with an internet company.)
#
# ### We will engineer a column for years of tenure and take a look at customers and their rates with that approach.  This will be done in our .py so it's created in the entire dataset, our train and test sets will both include this new feature.

# %%
pd.DataFrame(train.groupby(['internetservice', 'contract', 'churn'])['monthlycharges'].mean())
# Out:
#                                       monthlycharges
# internetservice contract       churn
# DSL             Month-to-month No          52.006973
#                                Yes         46.821245
#                 One year       No          61.565103
#                                Yes         61.962500
#                 Two year       No          70.147465
#                                Yes         67.425000
# Fiber optic     Month-to-month No          87.676488
#                                Yes         86.071402
#                 One year       No          97.831761
#                                Yes        102.347183
#                 Two year       No         104.168978
#                                Yes        103.488636
# No              Month-to-month No          20.327289
#                                Yes         20.226429
#                 One year       No          20.887952
#                                Yes         20.728571
#                 Two year       No          21.721625
#                                Yes         19.750000

# %% [markdown]
# ### I would have thought that customers that churned would be the higher paying customers.  This shows that they are not.

# %%
pd.DataFrame(train.groupby(['internetservice', 'contract', 'fullyear'])['monthlycharges'].mean())
# Out:
#                                          monthlycharges
# internetservice contract       fullyear
# DSL             Month-to-month 0              47.882096
#                                1              52.568132
#                                2              53.808036
#                                3              53.279464
#                                4              51.632432
#                                5              59.021875
#                 One year       0              53.072500
#                                1              59.692857
#                                2              62.054667
#                                3              61.093750
#                                4              63.422892
#                                5              64.102727
#                 Two year       0              54.750000
#                                1              56.700000
#                                2              67.144118
#                                3              67.252632
#                                4              67.137313
#                                5              70.679126
#                                6              76.972159
# Fiber optic     Month-to-month 0              81.562341
#                                1              86.753872
#                                2              89.384141
#                                3              92.264430
#                                4              94.635772
#                                5              97.736905
#                                6             112.900000
#                 One year       0              94.433333
#                                1              92.255882
#                                2              93.611905
#                                3              97.523770
#                                4              99.692273
#                                5             100.311724
#                                6             103.045455
#                 Two year       2              98.860000
#                                3              99.617857
#                                4              98.843056
#                                5             103.984043
#                                6             107.100000
# No              Month-to-month 0              20.233270
#                                1              20.505085
#                                2              20.806000
#                                3              19.620000
#                                4              20.000000
#                                5              19.400000
#                 One year       0              20.364583
#                                1              20.461111
#                                2              20.890385
#                                3              21.343056
#                                4              21.132895
#                                5              22.207895
#                 Two year       0              20.737037
#                                1              21.460417
#                                2              21.468889
#                                3              21.112500
#                                4              21.395455
#                                5              22.134926
#                                6              23.097561

# %% [markdown]
# ### As expected, almost all subgroups show a trend upwards in monthly charges.

# %%
pd.DataFrame(train.groupby(['internetservice', 'contract', 'fullyear'])['monthlycharges'].count())
# Out:
#                                          monthlycharges
# internetservice contract       fullyear
# DSL             Month-to-month 0                    458
#                                1                    182
#                                2                    112
#                                3                     56
#                                4                     37
#                                5                     16
#                 One year       0                     20
#                                1                     56
#                                2                     75
#                                3                     88
#                                4                     83
#                                5                     55
#                 Two year       0                     10
#                                1                     16
#                                2                     17
#                                3                     38
#                                4                     67
#                                5                    206
#                                6                     88
# Fiber optic     Month-to-month 0                    628
#                                1                    297
#                                2                    227
#                                3                    149
#                                4                    123
#                                5                     84
#                                6                      1
#                 One year       0                      3
#                                1                     17
#                                2                     42
#                                3                     61
#                                4                    110
#                                5                    145
#                                6                     11
#                 Two year       2                      5
#                                3                     14
#                                4                     36
#                                5                    141
#                                6                    100
# No              Month-to-month 0                    263
#                                1                     59
#                                2                     25
#                                3                      5
#                                4                      1
#                                5                      1
#                 One year       0                     48
#                                1                     63
#                                2                     52
#                                3                     36
#                                4                     38
#                                5                     19
#                 Two year       0                     27
#                                1                     48
#                                2                     45
#                                3                     64
#                                4                     77
#                                5                    136
#                                6                     41

# %%
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn', 'fullyear',
#        'gender_enc', 'partner_enc', 'dependents_enc', 'phoneservice_enc',
#        'multiplelines_enc', 'internetservice_enc', 'onlinesecurity_enc',
#        'onlinebackup_enc', 'deviceprotection_enc', 'techsupport_enc',
#        'streamingtv_enc', 'streamingmovies_enc', 'contract_enc',
#        'paperlessbilling_enc', 'paymentmethod_enc', 'churn_enc'],
#       dtype='object')

# %%
pd.DataFrame(train.groupby(['internetservice', 'contract', 'churn'])['churn'].count())
# Out:
#                                       churn
# internetservice contract       churn
# DSL             Month-to-month No       588
#                                Yes      273
#                 One year       No       341
#                                Yes       36
#                 Two year       No       434
#                                Yes        8
# Fiber optic     Month-to-month No       689
#                                Yes      820
#                 One year       No       318
#                                Yes       71
#                 Two year       No       274
#                                Yes       22
# No              Month-to-month No       284
#                                Yes       70
#                 One year       No       249
#                                Yes        7
#                 Two year       No       437
#                                Yes        1

# %% [markdown]
# ### Looking at the table above, we see that over half of fiber optic m-t-m churned.  DSL m-t-m had a high churn rate as well.

# %%
list(df[df.columns[df.nunique()<5]].select_dtypes(include=['object']).columns)
# Out:
# ['gender',
#  'partner',
#  'dependents',
#  'phoneservice',
#  'multiplelines',
#  'internetservice',
#  'onlinesecurity',
#  'onlinebackup',
#  'deviceprotection',
#  'techsupport',
#  'streamingtv',
#  'streamingmovies',
#  'contract',
#  'paperlessbilling',
#  'paymentmethod',
#  'churn']

# %% [markdown]
# ### We'll use the list above to run though crosstabs of these subgroups to take a look at any disproportionate amounts.

# %%
def chi_2_crosstab(df, target, list_of_variables):
    for col in list_of_variables:
        crosstab = pd.crosstab(df[target], df[col])
        print(crosstab)
        print(' ')
        print(str(col) + ':')
        print(stats.chi2_contingency(crosstab))
        print('-----')

# %%
object_vars = list(df[df.columns[df.nunique()<5]].select_dtypes(include=['object']).columns)
chi_2_crosstab(train, 'churn', object_vars)
# Out:
# gender  Female  Male
# churn
# No        1808  1806
# Yes        668   640
#
# gender:
# (0.3769912712380554, 0.5392178718511527, 1, array([[1818.01381552, 1795.98618448],
#        [ 657.98618448,  650.01381552]]))
# -----
# partner    No   Yes
# churn
# No       1680  1934
# Yes       848   460
#
# partner:
# (128.66094467328503, 8.045170424321452e-30, 1, array([[1856.19504267, 1757.80495733],
#        [ 671.80495733,  636.19504267]]))
# -----
# dependents    No   Yes
# churn
# No          2371  1243
# Yes         1081   227
#
# dependents:
# (132.31043409267664, 1.2796014891902146e-30, 1, array([[2534.64607883, 1079.35392117],
#        [ 917.35392117,  390.64607883]]))
# -----
# phoneservice   No   Yes
# churn
# No            356  3258
# Yes           116  1192
#
# phoneservice:
# (0.9581165651703833, 0.32766186444187695, 1, array([[ 346.56806176, 3267.43193824],
#        [ 125.43193824, 1182.56806176]]))
# -----
# multiplelines    No  No phone service   Yes
# churn
# No             1786               356  1472
# Yes             612               116   580
#
# multiplelines:
# (5.334882698645989, 0.06942964444251808, 2, array([[1760.74197481,  346.56806176, 1506.68996343],
#        [ 637.25802519,  125.43193824,  545.31003657]]))
# -----
# internetservice   DSL  Fiber optic   No
# churn
# No               1363         1281  970
# Yes               317          913   78
#
# internetservice:
# (502.01752028815326, 9.733758345325082e-110, 2, array([[1233.54733848, 1610.95408371,  769.49857781],
#        [ 446.45266152,  583.04591629,  278.50142219]]))
# -----
# onlinesecurity    No  No internet service   Yes
# churn
# No              1453                  970  1191
# Yes             1031                   78   199
#
# onlinesecurity:
# (587.434501050495, 2.755617011069707e-128, 2, array([[1823.88785047,  769.49857781, 1020.61357172],
#        [ 660.11214953,  278.50142219,  369.38642828]]))
# -----
# onlinebackup    No  No internet service   Yes
# churn
# No            1289                  970  1355
# Yes            869                   78   361
#
# onlinebackup:
# (430.95621379491297, 2.624503785249784e-94, 2, array([[1584.52092645,  769.49857781, 1259.98049573],
#        [ 573.47907355,  278.50142219,  456.01950427]]))
# -----
# deviceprotection    No  No internet service   Yes
# churn
# No                1314                  970  1330
# Yes                857                   78   373
#
# deviceprotection:
# (400.801438196472, 9.269867492435977e-88, 2, array([[1594.06623324,  769.49857781, 1250.43518895],
#        [ 576.93376676,  278.50142219,  452.56481105]]))
# -----
# techsupport    No  No internet service   Yes
# churn
# No           1444                  970  1200
# Yes          1016                   78   214
#
# techsupport:
# (564.837574939722, 2.2237144389832527e-123, 2, array([[1806.26574563,  769.49857781, 1038.23567655],
#        [ 653.73425437,  278.50142219,  375.76432345]]))
# -----
# streamingtv    No  No internet service   Yes
# churn
# No           1332                  970  1312
# Yes           675                   78   555
#
# streamingtv:
# (257.3322421564339, 1.3213370352520186e-56, 2, array([[1473.64851686,  769.49857781, 1370.85290532],
#        [ 533.35148314,  278.50142219,  496.14709468]]))
# -----
# streamingmovies    No  No internet service   Yes
# churn
# No               1295                  970  1349
# Yes               655                   78   575
#
# streamingmovies:
# (256.5812741253766, 1.9234648036728747e-56, 2, array([[1431.79601788,  769.49857781, 1412.70540431],
#        [ 518.20398212,  278.50142219,  511.29459569]]))
# -----
# contract  Month-to-month  One year  Two year
# churn
# No                  1561       908      1145
# Yes                 1163       114        31
#
# contract:
# (832.6766732158069, 1.5365893061731215e-181, 2, array([[2000.10889882,  750.40796424,  863.48313694],
#        [ 723.89110118,  271.59203576,  312.51686306]]))
# -----
# paperlessbilling    No   Yes
# churn
# No                1666  1948
# Yes                336   972
#
# paperlessbilling:
# (164.95923245562165, 9.337176493200688e-38, 1, array([[1469.97724502, 2144.02275498],
#        [ 532.02275498,  775.97724502]]))
# -----
# paymentmethod  Bank transfer (automatic)  Credit card (automatic)  \
# churn
# No                                   902                      883
# Yes                                  181                      171
#
# paymentmethod  Electronic check  Mailed check
# churn
# No                          920           909
# Yes                         749           207
#
# paymentmethod:
# (435.22385816171374, 5.18359259373172e-94, 3, array([[ 795.1974807 ,  773.90410402, 1225.47054043,  819.42787485],
#        [ 287.8025193 ,  280.09589598,  443.52945957,  296.57212515]]))
# -----
# churn    No   Yes
# churn
# No     3614     0
# Yes       0  1308
#
# churn:
# (4916.876411267068, 0.0, 1, array([[2653.59528647,  960.40471353],
#        [ 960.40471353,  347.59528647]]))
# -----

# %% [markdown]
# ### Looking at just the numbers above, we see some disproportionate groups comparing churn vs. non-churned customers.  We'll visualize these in another notebook to make it more apparent.

# %% [markdown]
# ### We have quite a few features that have very low p-values.  Let's try running a model with anything under 5%, followed by two more models with the extremely low p-values.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import tree
from sklearn.preprocessing import StandardScaler

# %%
y_train = train[['churn_enc']]
y_test = test[['churn_enc']]
X_train = train[['partner_enc', 'dependents_enc', 'internetservice_enc', 'onlinesecurity_enc', 
                 'onlinebackup_enc', 'deviceprotection_enc', 'techsupport_enc',
                 'streamingtv_enc', 'streamingmovies_enc', 'contract_enc',
                 'paperlessbilling_enc', 'paymentmethod_enc']]
X_test = test[['partner_enc', 'dependents_enc', 'internetservice_enc', 'onlinesecurity_enc', 
                 'onlinebackup_enc', 'deviceprotection_enc', 'techsupport_enc',
                 'streamingtv_enc', 'streamingmovies_enc', 'contract_enc',
                 'paperlessbilling_enc', 'paymentmethod_enc']]

clf = DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=123).fit(X_train, y_train)
y_pred = clf.predict(X_train)
y_pred_proba = clf.predict_proba(X_train)
print('Accuracy of Decision Tree classifier on training set: {:.6f}'
     .format(clf.score(X_train, y_train)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.783015

# %%
y_train = train[['churn_enc']]
y_test = test[['churn_enc']]
X_train = train[['internetservice_enc', 'onlinesecurity_enc', 
                 'techsupport_enc',
                 'contract_enc', 'tenure', 'monthlycharges']]
X_test = test[['internetservice_enc', 'onlinesecurity_enc', 
                 'techsupport_enc',
                 'contract_enc', 'tenure', 'monthlycharges']]

clf = DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=123).fit(X_train, y_train)
y_pred = clf.predict(X_train)
y_pred_proba = clf.predict_proba(X_train)
print('Accuracy of Decision Tree classifier on training set: {:.6f}'
     .format(clf.score(X_train, y_train)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.801910

# %%
y_train = train[['churn_enc']]
y_test = test[['churn_enc']]
X_train = train[['internetservice_enc', 'onlinesecurity_enc', 
                 'onlinebackup_enc', 'deviceprotection_enc', 'techsupport_enc',
                 'contract_enc', 'tenure', 'monthlycharges',
                 'paymentmethod_enc']]
X_test = test[['internetservice_enc', 'onlinesecurity_enc', 
                 'onlinebackup_enc', 'deviceprotection_enc', 'techsupport_enc',
                 'contract_enc', 'tenure', 'monthlycharges',
                 'paymentmethod_enc']]

clf = DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=123).fit(X_train, y_train)
y_pred = clf.predict(X_train)
y_pred_proba = clf.predict_proba(X_train)
print('Accuracy of Decision Tree classifier on training set: {:.6f}'
     .format(clf.score(X_train, y_train)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.802519

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      3614
#            1       0.67      0.52      0.58      1308
#
#    micro avg       0.80      0.80      0.80      4922
#    macro avg       0.75      0.71      0.73      4922
# weighted avg       0.79      0.80      0.79      4922

# %%
cm = pd.DataFrame(confusion_matrix(y_train, y_pred),
             columns=['Pred -', 'Pred +'], index=['Actual -', 'Actual +'])

cm
# Out:
#           Pred -  Pred +
# Actual -    3276     338
# Actual +     634     674

# %%
log_reg = LogisticRegression(random_state=123, solver='saga').fit(X_train, y_train)
y_pred = log_reg.predict(X_train)
print('Accuracy of Logistic Regression classifier on training set: {:.6f}'
     .format(log_reg.score(X_train, y_train)))
# Out:
# Accuracy of Logistic Regression classifier on training set: 0.791142

# %%
rf = RandomForestClassifier(bootstrap=True, 
                            class_weight=None, 
                            criterion='gini',
                            min_samples_leaf=3,
                            n_estimators=100,
                            max_depth=6, 
                            random_state=123)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_train)
print('Accuracy of random forest classifier on training set: {:.6f}'
     .format(rf.score(X_train, y_train)))
# Out:
# Accuracy of random forest classifier on training set: 0.812271

# %% [markdown]
# ### We have run a few variations of features used.  The logistic regression model above is using the highest accuracy of those features as well.  At this point, we'll use our best combination of features and run them on the test set using the decision tree model that was just above 80% accuracy above.

# %%
print('Accuracy of Decision Tree classifier on test set: {:.6f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on test set: 0.788152

# %%
print('Accuracy of Random Forest classifier on test set: {:.6f}'
     .format(rf.score(X_test, y_test)))
# Out:
# Accuracy of Random Forest classifier on test set: 0.792891
